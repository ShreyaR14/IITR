# %% [markdown]
# <a href="https://colab.research.google.com/github/ShreyaR14/IITR/blob/master/Module%201/FeatureVector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# import numpy as np
# import cv2
# import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import cv2 
from skimage.feature import hog
from skimage import exposure
from skimage.io import imread, imshow

# %matplotlib inline

# %% [markdown]
# ## Training Data

# %%
file  = "/content/drive/My Drive/Mod1-IITR/fishplate/pos/1.PNG"
image = plt.imread(file)

fd, hog_image = hog(image, orientations=15, pixels_per_cell=(20, 20), cells_per_block=(2, 2), visualize=True, block_norm="L1", transform_sqrt=False)
# display the image
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4), sharex=True, sharey=True)

ax1.axis('off')
ax1.imshow(image, cmap=plt.cm.gray)
ax1.set_title('Input image')

# Rescale histogram for better display
hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 10))
# display the HOG features
ax2.axis('off')
ax2.imshow(hog_image_rescaled, cmap=plt.cm.gray)
ax2.set_title('Histogram of Oriented Gradients')
# Out:
# Text(0.5, 1.0, 'Histogram of Oriented Gradients')

# %%
from skimage.io import imread, imshow
image = imread('/content/drive/My Drive/Mod1-IITR/fishplate/pos/1.PNG', as_gray=True)

#checking image shape 
print('Shape of the image is = ',image.shape)

# image matrix
print('\n\nImage matrix\n\n',image)

# create features
features = np.reshape(image, (97*117))

# shape of feature array
print('\n\nShape of the feature array = ',features.shape)

print('\n\nFeature Array\n\n',features)
# Out:
# Shape of the image is =  (97, 117)
#
#
# Image matrix
#
#  [[0.16296392 0.16296392 0.16296392 ... 0.14446431 0.16015059 0.17583686]
#  [0.16296392 0.16296392 0.16296392 ... 0.13662118 0.14838588 0.16407216]
#  [0.16688549 0.16296392 0.16576941 ... 0.12877804 0.14446431 0.15622902]
#  ...
#  [0.14505255 0.15261294 0.16354431 ... 0.17191529 0.17695294 0.18368   ]
#  [0.15206235 0.16354431 0.17447569 ... 0.16407216 0.17191529 0.17583686]
#  [0.15907216 0.17083686 0.18260157 ... 0.15651176 0.16407216 0.17191529]]
#
#
# Shape of the feature array =  (11349,)
#
#
# Feature Array
#
#  [0.16296392 0.16296392 0.16296392 ... 0.15651176 0.16407216 0.17191529]

# %%
file  = "/content/drive/My Drive/Mod1-IITR/fishplate/pos/2.PNG"
image = plt.imread(file)

fd, hog_image = hog(image, orientations=15, pixels_per_cell=(20, 20), cells_per_block=(2, 2), visualize=True, block_norm="L1", transform_sqrt=False)
# display the image
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4), sharex=True, sharey=True)

ax1.axis('off')
ax1.imshow(image, cmap=plt.cm.gray)
ax1.set_title('Input image')

# Rescale histogram for better display
hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 10))
# display the HOG features
ax2.axis('off')
ax2.imshow(hog_image_rescaled, cmap=plt.cm.gray)
ax2.set_title('Histogram of Oriented Gradients')
# Out:
# Text(0.5, 1.0, 'Histogram of Oriented Gradients')

# %%
from skimage.io import imread, imshow
image = imread('/content/drive/My Drive/Mod1-IITR/fishplate/pos/2.PNG', as_gray=True)

#checking image shape 
print('Shape of the image is = ',image.shape)

# image matrix
print('\n\nImage matrix\n\n',image)

# create features
features = np.reshape(image, (95*107))

# shape of feature array
print('\n\nShape of the feature array = ',features.shape)

print('\n\nFeature Array\n\n',features)
# Out:
# Shape of the image is =  (95, 107)
#
#
# Image matrix
#
#  [[0.10554627 0.08986    0.06941882 ... 0.14528275 0.13743961 0.13715686]
#  [0.10526353 0.08593843 0.06941882 ... 0.14528275 0.14107843 0.13827294]
#  [0.10162471 0.08593843 0.06913608 ... 0.14920431 0.14219451 0.14136118]
#  ...
#  [0.14924196 0.15316353 0.1570851  ... 0.22739059 0.22346902 0.22346902]
#  [0.14924196 0.14952471 0.15344627 ... 0.22346902 0.21954745 0.21954745]
#  [0.14615373 0.14924196 0.14952471 ... 0.21954745 0.21562588 0.21562588]]
#
#
# Shape of the feature array =  (10165,)
#
#
# Feature Array
#
#  [0.10554627 0.08986    0.06941882 ... 0.21954745 0.21562588 0.21562588]

# %%
file  = "/content/drive/My Drive/Mod1-IITR/fishplate/pos/3.PNG"
image = plt.imread(file)

fd, hog_image = hog(image, orientations=15, pixels_per_cell=(20, 20), cells_per_block=(2, 2), visualize=True, block_norm="L1", transform_sqrt=False)
# display the image
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4), sharex=True, sharey=True)

ax1.axis('off')
ax1.imshow(image, cmap=plt.cm.gray)
ax1.set_title('Input image')

# Rescale histogram for better display
hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 10))
# display the HOG features
ax2.axis('off')
ax2.imshow(hog_image_rescaled, cmap=plt.cm.gray)
ax2.set_title('Histogram of Oriented Gradients')
# Out:
# Text(0.5, 1.0, 'Histogram of Oriented Gradients')

# %%
from skimage.io import imread, imshow
image = imread('/content/drive/My Drive/Mod1-IITR/fishplate/pos/3.PNG', as_gray=True)

#checking image shape 
print('Shape of the image is = ',image.shape)

# image matrix
print('\n\nImage matrix\n\n',image)

# create features
features = np.reshape(image, (77*86))

# shape of feature array
print('\n\nShape of the feature array = ',features.shape)

print('\n\nFeature Array\n\n',features)
# Out:
# Shape of the image is =  (77, 86)
#
#
# Image matrix
#
#  [[0.07872118 0.08152667 0.08152667 ... 0.12569765 0.13354078 0.14221725]
#  [0.07843843 0.07843843 0.08152667 ... 0.14922706 0.16099176 0.1688349 ]
#  [0.0776051  0.0776051  0.0776051  ... 0.17387255 0.18955882 0.20020745]
#  ...
#  [0.0582651  0.06218667 0.06919647 ... 0.24585961 0.25370275 0.25762431]
#  [0.05462627 0.0582651  0.0652749  ... 0.25370275 0.26154588 0.26546745]
#  [0.05434353 0.05434353 0.06135333 ... 0.26154588 0.26938902 0.27331059]]
#
#
# Shape of the feature array =  (6622,)
#
#
# Feature Array
#
#  [0.07872118 0.08152667 0.08152667 ... 0.26154588 0.26938902 0.27331059]

# %%
file  = "/content/drive/My Drive/Mod1-IITR/fishplate/pos/4.PNG"
image = plt.imread(file)

fd, hog_image = hog(image, orientations=15, pixels_per_cell=(20, 20), cells_per_block=(2, 2), visualize=True, block_norm="L1", transform_sqrt=False)
# display the image
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4), sharex=True, sharey=True)

ax1.axis('off')
ax1.imshow(image, cmap=plt.cm.gray)
ax1.set_title('Input image')

# Rescale histogram for better display
hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 10))
# display the HOG features
ax2.axis('off')
ax2.imshow(hog_image_rescaled, cmap=plt.cm.gray)
ax2.set_title('Histogram of Oriented Gradients')
# Out:
# Text(0.5, 1.0, 'Histogram of Oriented Gradients')

# %%
from skimage.io import imread, imshow
image = imread('/content/drive/My Drive/Mod1-IITR/fishplate/pos/4.PNG', as_gray=True)

#checking image shape 
print('Shape of the image is = ',image.shape)

# image matrix
print('\n\nImage matrix\n\n',image)

# create features
features = np.reshape(image, (68*87))

# shape of feature array
print('\n\nShape of the feature array = ',features.shape)

print('\n\nFeature Array\n\n',features)
# Out:
# Shape of the image is =  (68, 87)
#
#
# Image matrix
#
#  [[0.09329137 0.09329137 0.09329137 ... 0.20581843 0.22570902 0.24895569]
#  [0.0893698  0.09329137 0.09329137 ... 0.20189686 0.22150471 0.24391804]
#  [0.08544824 0.0893698  0.09329137 ... 0.19405373 0.21730039 0.24111255]
#  ...
#  [0.08543333 0.0893549  0.09719804 ... 0.2434051  0.22379725 0.20502275]
#  [0.0893549  0.09719804 0.10504118 ... 0.22379725 0.20811098 0.19214196]
#  [0.10504118 0.10896275 0.11400039 ... 0.20418941 0.19242471 0.17645569]]
#
#
# Shape of the feature array =  (5916,)
#
#
# Feature Array
#
#  [0.09329137 0.09329137 0.09329137 ... 0.20418941 0.19242471 0.17645569]

# %%
file  = "/content/drive/My Drive/Mod1-IITR/fishplate/pos/5.PNG"
image = plt.imread(file)

fd, hog_image = hog(image, orientations=15, pixels_per_cell=(20, 20), cells_per_block=(2, 2), visualize=True, block_norm="L1", transform_sqrt=False)
# display the image
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4), sharex=True, sharey=True)

ax1.axis('off')
ax1.imshow(image, cmap=plt.cm.gray)
ax1.set_title('Input image')

# Rescale histogram for better display
hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 10))
# display the HOG features
ax2.axis('off')
ax2.imshow(hog_image_rescaled, cmap=plt.cm.gray)
ax2.set_title('Histogram of Oriented Gradients')
# Out:
# Text(0.5, 1.0, 'Histogram of Oriented Gradients')

# %%
from skimage.io import imread, imshow
image = imread('/content/drive/My Drive/Mod1-IITR/fishplate/pos/5.PNG', as_gray=True)

#checking image shape 
print('Shape of the image is = ',image.shape)

# image matrix
print('\n\nImage matrix\n\n',image)

# create features
features = np.reshape(image, (75*88))

# shape of feature array
print('\n\nShape of the feature array = ',features.shape)

print('\n\nFeature Array\n\n',features)
# Out:
# Shape of the image is =  (75, 88)
#
#
# Image matrix
#
#  [[0.12069765 0.11705882 0.11230392 ... 0.2169949  0.24948353 0.28477765]
#  [0.12854078 0.12490196 0.12014706 ... 0.25228902 0.28477765 0.31923843]
#  [0.13638392 0.13191176 0.1279902  ... 0.28703255 0.31923843 0.35453255]
#  ...
#  [0.07194941 0.07615373 0.07952471 ... 0.33242471 0.32850314 0.32374824]
#  [0.07587098 0.08007529 0.08344627 ... 0.34363882 0.33971725 0.33943451]
#  [0.08007529 0.08399686 0.08736784 ... 0.3545702  0.3545702  0.3545702 ]]
#
#
# Shape of the feature array =  (6600,)
#
#
# Feature Array
#
#  [0.12069765 0.11705882 0.11230392 ... 0.3545702  0.3545702  0.3545702 ]

# %% [markdown]
# ## Testing Image

# %%
file  = "/content/drive/My Drive/Mod1-IITR/314_1.PNG"
image = plt.imread(file)

fd, hog_image = hog(image, orientations=15, pixels_per_cell=(20, 20), cells_per_block=(2, 2), visualize=True, block_norm="L1", transform_sqrt=False)
# display the image
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4), sharex=True, sharey=True)

ax1.axis('off')
ax1.imshow(image, cmap=plt.cm.gray)
ax1.set_title('Input image')

# Rescale histogram for better display
hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 10))
# display the HOG features
ax2.axis('off')
ax2.imshow(hog_image_rescaled, cmap=plt.cm.gray)
ax2.set_title('Histogram of Oriented Gradients')
# Out:
# Text(0.5, 1.0, 'Histogram of Oriented Gradients')

# %%
from skimage.io import imread, imshow
image = imread('/content/drive/My Drive/Mod1-IITR/314_1.PNG', as_gray=True)

#checking image shape 
print('Shape of the image is = ',image.shape)

# image matrix
print('\n\nImage matrix\n\n',image)

# create features
features = np.reshape(image, (145*249))

# shape of feature array
print('\n\nShape of the feature array = ',features.shape)

print('\n\nFeature Array\n\n',features)
# Out:
# Shape of the image is =  (145, 249)
#
#
# Image matrix
#
#  [[0.30325451 0.33070549 0.3542349  ... 0.18571961 0.19665098 0.19384549]
#  [0.28756824 0.31501922 0.33854863 ... 0.18600235 0.19384549 0.19412824]
#  [0.27188196 0.29933294 0.32678392 ... 0.19384549 0.1980498  0.1980498 ]
#  ...
#  [0.39909922 0.39798314 0.39517765 ... 0.25323451 0.25351725 0.25632275]
#  [0.40413686 0.40021529 0.40021529 ... 0.26416588 0.26808745 0.26808745]
#  [0.39993255 0.39320549 0.39237216 ... 0.25996157 0.26388314 0.26388314]]
#
#
# Shape of the feature array =  (36105,)
#
#
# Feature Array
#
#  [0.30325451 0.33070549 0.3542349  ... 0.25996157 0.26388314 0.26388314]
